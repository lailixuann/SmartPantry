# %%
# %cd /kaggle/working/
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# /kaggle/working
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /kaggle/working/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !cat /kaggle/input/ingredients/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 17
# names: ['beef', 'cabbage', 'chicken', 'chili_pepper', 'cilantro', 'egg', 'fish', 'garlic', 'ginger', 'green_onion', 'lime', 'mango', 'noodles', 'onion', 'pork', 'potato', 'tomato']
#
# roboflow:
#   workspace: smartpantry-mispl
#   project: ingredients_detection-shwnt-bpwxf
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/smartpantry-mispl/ingredients_detection-shwnt-bpwxf/dataset/1

# %%
# !cp -r /kaggle/input/ingredients /kaggle/working/yolov5

# %%
# %%writefile /kaggle/working/yolov5/ingredients/data.yaml
# train: ../ingredients/train/images
# val: ../ingredients/valid/images
#
# nc: 17
# names: ['beef', 'cabbage', 'chicken', 'chili_pepper', 'cilantro', 'egg', 'fish', 'garlic', 'ginger', 'green_onion', 'lime', 'mango', 'noodles', 'onion', 'pork', 'potato', 'tomato']
#
# roboflow:
#   workspace: smartpantry-mispl
#   project: ingredients_detection-shwnt-bpwxf
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/smartpantry-mispl/ingredients_detection-shwnt-bpwxf/dataset/1
# Out:
# Overwriting /kaggle/working/yolov5/ingredients/data.yaml

# %%
# %cd /kaggle/working/yolov5
# !WANDB_MODE=disabled python train.py \
  --img 640 \
  --batch 16 \
  --epochs 50 \
  --data ingredients/data.yaml \
  --weights yolov5s.pt \
  --project yolov5-ingredients
# Out:
# /kaggle/working/yolov5
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-06-11 15:23:33.879016: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749655413.901824     209 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749655413.908631     209 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !zip -r /kaggle/working/yolo_results.zip /kaggle/working/yolov5/yolov5-ingredients/exp2/
# Out:
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/ (stored 0%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/val_batch0_labels.jpg (deflated 8%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/PR_curve.png (deflated 4%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/hyp.yaml (deflated 45%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/val_batch0_pred.jpg (deflated 8%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/results.csv (deflated 83%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/train_batch2.jpg (deflated 6%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/R_curve.png (deflated 3%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/val_batch2_labels.jpg (deflated 11%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/events.out.tfevents.1749655416.e360f74a49c0.209.0 (deflated 15%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp2/train_batch1.jpg (deflated 10%)
# ...
