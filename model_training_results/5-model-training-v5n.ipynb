# %%
# %cd /kaggle/working/
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# /kaggle/working
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 17516 (delta 7), reused 0 (delta 0), pack-reused 17493 (from 3)
# Receiving objects: 100% (17516/17516), 16.60 MiB | 27.83 MiB/s, done.
# Resolving deltas: 100% (11995/11995), done.
# /kaggle/working/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.8 MB/s eta 0:00:00
# ...

# %%
# !cat /kaggle/input/ingredients-v3/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 16
# names: ['beef', 'cabbage', 'chicken', 'chili_pepper', 'cilantro', 'egg', 'fish', 'garlic', 'ginger', 'green_onion', 'lime', 'mango', 'noodles', 'onion', 'potato', 'tomato']
#
# roboflow:
#   workspace: smartpantry-mispl
#   project: ingredients_detection-shwnt-bpwxf
#   version: 4
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/smartpantry-mispl/ingredients_detection-shwnt-bpwxf/dataset/4

# %%
# !cp -r /kaggle/input/ingredients-v3 /kaggle/working/yolov5

# %%
# %%writefile /kaggle/working/yolov5/ingredients-v3/data.yaml
# train: ../ingredients-v3/train/images
# val: ../ingredients-v3/valid/images
# test: ../ingredients-v3/test/images]
#
# nc: 16
# names: ['beef', 'cabbage', 'chicken', 'chili_pepper', 'cilantro', 'egg', 'fish', 'garlic', 'ginger', 'green_onion', 'lime', 'mango', 'noodles', 'onion', 'potato', 'tomato']
#
# roboflow:
#   workspace: smartpantry-mispl
#   project: ingredients_detection-shwnt-bpwxf
#   version: 4
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/smartpantry-mispl/ingredients_detection-shwnt-bpwxf/dataset/4
# Out:
# Overwriting /kaggle/working/yolov5/ingredients-v3/data.yaml

# %%
# %cd /kaggle/working/yolov5
# !WANDB_MODE=disabled python train.py \
  --img 640 \
  --batch 16 \
  --epochs 80 \
  --data ingredients-v3/data.yaml \
  --weights yolov5n.pt \
  --project yolov5-ingredients \
  --device 0,1 \
  --patience 10
# Out:
# /kaggle/working/yolov5
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-14 11:13:14.144482: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752491594.482911     105 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !zip -r /kaggle/working/yolo_results.zip /kaggle/working/yolov5/yolov5-ingredients/exp/
# Out:
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/ (stored 0%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/results.png (deflated 9%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/val_batch0_pred.jpg (deflated 7%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/weights/ (stored 0%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/weights/best.pt (deflated 13%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/weights/last.pt (deflated 13%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/R_curve.png (deflated 3%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/results.csv (deflated 83%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/val_batch0_labels.jpg (deflated 8%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/events.out.tfevents.1752491608.3fd8e7e87a71.105.0 (deflated 17%)
#   adding: kaggle/working/yolov5/yolov5-ingredients/exp/confusion_matrix.png (deflated 16%)
# ...

# %%
# !cd /Users/lailixuan/Downloads/PRJ3223_Capstone2/SmartPantry/yolov5
# !python /Users/lailixuan/Downloads/PRJ3223_Capstone2/SmartPantry/yolov5/val.py \
 --weights /Users/lailixuan/Downloads/PRJ3223_Capstone2/SmartPantry/FINAL_Results/5_v5n_DatasetB_refined/working/yolov5/yolov5-ingredients/exp/weights/best.pt \
 --data /Users/lailixuan/Downloads/PRJ3223_Capstone2/SmartPantry/FINAL_Results/dataset_B/data.yaml \
 --img 640
# Out:
# /Users/lailixuan/Downloads/PRJ3223_Capstone2/SmartPantry/yolov5/utils/general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# val: data=/Users/lailixuan/Downloads/PRJ3223_Capstone2/SmartPantry/FINAL_Results/dataset_B/data.yaml, weights=['/Users/lailixuan/Downloads/PRJ3223_Capstone2/SmartPantry/FINAL_Results/5_v5n_DatasetB_refined/working/yolov5/yolov5-ingredients/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=../yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-420-g0c99ce80 Python-3.10.13 torch-2.7.1 CPU
#
# ...
